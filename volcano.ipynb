# %% [markdown]
# ## Volcano plot
#
# source: https://www.reneshbedre.com/blog/volcano.html

# %%
import pandas as pd

# %%
from bioinfokit import analys, visuz

# %%
df = pd.read_csv('srr_cispla/TEtranscripts_results/A2780_deseq_all.csv')

# %%
df
# Out:
#                         baseMean   baseMean.1  log2FoldChange     lfcSE  \
# 0                 L1PA16:L1:LINE  6907.689423       -0.715035  0.045014
# 1                MER74C:ERVL:LTR   168.057517       -1.711042  0.158471
# 2                  L1MEc:L1:LINE  7429.815759       -0.575529  0.042107
# 3                  L1MD1:L1:LINE  3291.192880       -0.703996  0.047496
# 4                 MLT2D:ERVL:LTR   746.491258       -0.409737  0.080674
# ...                          ...          ...             ...       ...
# 1035  Tigger14a:TcMar-Tigger:DNA   188.865133       -0.724437  0.160425
# 1036              LTR87:ERVL:LTR   678.251308       -0.369384  0.081603
# 1037                L1P5:L1:LINE    72.585359       -1.017259  0.224215
# 1038              MER135:DNA:DNA   124.607612       -0.806012  0.177416
# 1039         MLT1E:ERVL-MaLR:LTR   209.931469       -0.646365  0.142239
#
#            stat        pvalue          padj
# 0    -15.884584  8.103407e-57  9.745698e-54
# ...

# %%
df['log2FoldChange'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### A2780

# %%
visuz.GeneExpression.volcano(df=df, lfc='log2FoldChange', pv='padj', color=("#00239CFF", "grey", "#E10600FF"), lfc_thr=(1, 1), pv_thr=(0.05, 0.05), valpha=0.5, dotsize=25,  xlm=(-3,2,0.5), ylm=(0,101,20), sign_line=True, show=False)
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# ...

# %% [markdown]
# ### Acis

# %%
visuz.GeneExpression.volcano(df=df, lfc='log2FoldChange', pv='padj', color=("#00239CFF", "grey", "#E10600FF"), lfc_thr=(1, 1), pv_thr=(0.05, 0.05), valpha=0.5, dotsize=25, sign_line=True, markerdot='*', xlm=(-3,2,0.5), ylm=(0,101,20), show=False)
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# ...
